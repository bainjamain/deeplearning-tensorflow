# %% [markdown]
# # Generative Adversarial Network (GAN)

# %%
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Let's load the MNIST data set.

# %%
transform = torchvision.transforms.Compose([torchvision.transforms.ToTensor(),
                                torchvision.transforms.Normalize(mean=(.5, .5, .5), std=(.5, .5, .5))])
mnist = torchvision.datasets.MNIST(root='../data/', train=True, transform=transform, download=True)

# %% [markdown]
# We define some hyperparameters.

# %%
batch =  100

# Discriminator
input_size_d = 28 * 28
hidden_size_d = 256
output_size_d = 1 # probability
learning_rate_d = .0005

# Generator
input_size_g = 128
hidden_size_g = 256
output_size_g = input_size_d # output of generator is a flatten image
learning_rate_g = .0005

epochs = 100

# %% [markdown]
# Create a *loader* to feed the data batch by batch during training.

# %%
data_loader = torch.utils.data.DataLoader(mnist, batch_size=batch, shuffle=True)

# %% [markdown]
# Now, we define the architectures of the **discriminator** and **generator**.

# %%
discriminator = nn.Sequential(
            nn.Linear(input_size_d, hidden_size_d),
            nn.ReLU(),
            nn.Linear(hidden_size_d, hidden_size_d),
            nn.ReLU(),
            nn.Linear(hidden_size_d, output_size_d),
            nn.Sigmoid())

generator = nn.Sequential(
            nn.Linear(input_size_g, hidden_size_g),
            nn.LeakyReLU(),
            nn.Linear(hidden_size_g, hidden_size_g),
            nn.LeakyReLU(),
            nn.Linear(hidden_size_g, output_size_g),
            nn.Tanh())

# %% [markdown]
# We define the loss function and the optimization schemes (here **Adam**) for both the discriminator and the generator.

# %%
criterion = nn.BCELoss()
optimizer_discriminator = torch.optim.Adam(params=discriminator.parameters(), lr=learning_rate_d)
optimizer_generator = torch.optim.Adam(params=generator.parameters(), lr=learning_rate_g)

# %% [markdown]
# Finally, we train the discriminator and the generator together.

# %%
data_size = int(mnist.train_labels.size()[0])

d_x = 0. # average classification probabilities of real data
d_g_z = 0. # average classification probabilities of fake data
loss_d = 0. # average loss of discriminator
loss_g = 0. # average loss of generator

for i in range(epochs):
    for j, (images, _) in enumerate(data_loader):
        images = images.view(images.size(0), -1) # map tensor from [batch, 1, 28, 28] to [batch, 28 * 28]
        real_images = Variable(images)
        
        
        # ******************
        # Discriminator step
        # ******************
        discriminator.zero_grad()
        
        noise = Variable(torch.randn(batch, input_size_g))
        fake_images = generator(noise) # map input noise to the data space (image)
        discriminator_real = discriminator(real_images)
        discriminator_fake = discriminator(fake_images.detach())
        real_loss_discriminator = criterion(discriminator_real, Variable(torch.ones(discriminator_real.size())))
        fake_loss_discriminator = criterion(discriminator_fake, Variable(torch.zeros(discriminator_fake.size())))
        
        loss_discriminator = real_loss_discriminator + fake_loss_discriminator
        loss_discriminator.backward()
        optimizer_discriminator.step()
        
        
        # ******************
        # * Generator step *
        # ******************
        generator.zero_grad()
        
        noise = Variable(torch.randn(batch, input_size_g))
        fake_images = generator(noise) # map input noise to the data space (image)
        discriminator_fake2 = discriminator(fake_images)
        loss_generator = criterion(discriminator_fake2, Variable(torch.ones(discriminator_fake2.size())))
        loss_generator.backward()
        optimizer_generator.step()
        
        d_x += torch.sum(discriminator_real).data[0] / data_size
        d_g_z += torch.sum(discriminator_fake).data[0] / data_size
        loss_d += loss_discriminator.data[0] / (data_size / batch)
        loss_g += loss_generator.data[0] / (data_size / batch)
        

    print('Epoch %i/%i, d_loss: %.2f, g_loss: %.2f, D(X)=%.2f D(G(Z))=%.2f' % 
                (i + 1, epochs, loss_d,
                loss_g, d_x, d_g_z))    
    d_x, d_g_z, loss_d, loss_g = 0., 0., 0., 0.
            
    fake_images = fake_images.view(batch, 1, 28, 28)
    torchvision.utils.save_image(fake_images.data, 
        '../fake_images/fake_samples_%d.png' % (i + 1))
# Out:
# Epoch 0/100, d_loss: 0.46, g_loss: 4.59, D(X)=0.91 D(G(Z))=0.18
# Epoch 1/100, d_loss: 1.31, g_loss: 2.56, D(X)=0.69 D(G(Z))=0.36
# Epoch 2/100, d_loss: 1.27, g_loss: 1.08, D(X)=0.61 D(G(Z))=0.45
# Epoch 3/100, d_loss: 1.27, g_loss: 1.40, D(X)=0.62 D(G(Z))=0.42
# Epoch 4/100, d_loss: 1.32, g_loss: 1.66, D(X)=0.63 D(G(Z))=0.41
# Epoch 5/100, d_loss: 1.52, g_loss: 1.28, D(X)=0.59 D(G(Z))=0.45
# Epoch 6/100, d_loss: 1.37, g_loss: 0.95, D(X)=0.57 D(G(Z))=0.47
# Epoch 7/100, d_loss: 1.09, g_loss: 1.76, D(X)=0.67 D(G(Z))=0.35
# Epoch 8/100, d_loss: 0.94, g_loss: 2.75, D(X)=0.74 D(G(Z))=0.28
# Epoch 9/100, d_loss: 1.14, g_loss: 2.57, D(X)=0.69 D(G(Z))=0.32
# Epoch 10/100, d_loss: 1.20, g_loss: 1.44, D(X)=0.63 D(G(Z))=0.39
# Epoch 11/100, d_loss: 1.34, g_loss: 1.22, D(X)=0.59 D(G(Z))=0.43
# Epoch 12/100, d_loss: 1.21, g_loss: 1.36, D(X)=0.61 D(G(Z))=0.40
# Epoch 13/100, d_loss: 1.30, g_loss: 1.48, D(X)=0.61 D(G(Z))=0.40
# Epoch 14/100, d_loss: 1.16, g_loss: 1.42, D(X)=0.64 D(G(Z))=0.37
# Epoch 15/100, d_loss: 1.07, g_loss: 1.96, D(X)=0.68 D(G(Z))=0.33
# Epoch 16/100, d_loss: 1.18, g_loss: 1.33, D(X)=0.61 D(G(Z))=0.39
# Epoch 17/100, d_loss: 1.01, g_loss: 1.48, D(X)=0.66 D(G(Z))=0.35
# Epoch 18/100, d_loss: 0.87, g_loss: 2.10, D(X)=0.73 D(G(Z))=0.28
# Epoch 19/100, d_loss: 0.79, g_loss: 3.36, D(X)=0.78 D(G(Z))=0.23
# Epoch 20/100, d_loss: 0.73, g_loss: 2.96, D(X)=0.79 D(G(Z))=0.22
# Epoch 21/100, d_loss: 0.81, g_loss: 2.61, D(X)=0.77 D(G(Z))=0.24
# Epoch 22/100, d_loss: 0.97, g_loss: 2.12, D(X)=0.73 D(G(Z))=0.29
# Epoch 23/100, d_loss: 0.95, g_loss: 1.93, D(X)=0.72 D(G(Z))=0.29
# Epoch 24/100, d_loss: 1.03, g_loss: 1.59, D(X)=0.68 D(G(Z))=0.33
# Epoch 25/100, d_loss: 1.00, g_loss: 1.86, D(X)=0.70 D(G(Z))=0.31
# Epoch 26/100, d_loss: 1.00, g_loss: 1.76, D(X)=0.70 D(G(Z))=0.31
# Epoch 27/100, d_loss: 1.01, g_loss: 2.71, D(X)=0.74 D(G(Z))=0.28
# Epoch 28/100, d_loss: 1.05, g_loss: 1.79, D(X)=0.69 D(G(Z))=0.32
# Epoch 29/100, d_loss: 1.07, g_loss: 1.95, D(X)=0.69 D(G(Z))=0.31
# Epoch 30/100, d_loss: 0.97, g_loss: 2.33, D(X)=0.73 D(G(Z))=0.28
# Epoch 31/100, d_loss: 0.95, g_loss: 2.20, D(X)=0.73 D(G(Z))=0.28
# Epoch 32/100, d_loss: 0.86, g_loss: 1.98, D(X)=0.75 D(G(Z))=0.27
# Epoch 33/100, d_loss: 0.88, g_loss: 2.13, D(X)=0.75 D(G(Z))=0.27
# Epoch 34/100, d_loss: 0.82, g_loss: 2.01, D(X)=0.75 D(G(Z))=0.26
# Epoch 35/100, d_loss: 1.00, g_loss: 2.73, D(X)=0.74 D(G(Z))=0.27
# Epoch 36/100, d_loss: 0.89, g_loss: 1.93, D(X)=0.73 D(G(Z))=0.28
# Epoch 37/100, d_loss: 0.82, g_loss: 1.91, D(X)=0.74 D(G(Z))=0.27
# Epoch 38/100, d_loss: 0.88, g_loss: 2.12, D(X)=0.74 D(G(Z))=0.27
# Epoch 39/100, d_loss: 0.88, g_loss: 1.94, D(X)=0.73 D(G(Z))=0.28
# Epoch 40/100, d_loss: 0.84, g_loss: 1.92, D(X)=0.74 D(G(Z))=0.27
# Epoch 41/100, d_loss: 0.83, g_loss: 1.89, D(X)=0.74 D(G(Z))=0.27
# Epoch 42/100, d_loss: 0.82, g_loss: 2.11, D(X)=0.75 D(G(Z))=0.26
# Epoch 43/100, d_loss: 0.84, g_loss: 2.47, D(X)=0.76 D(G(Z))=0.24
# Epoch 44/100, d_loss: 0.87, g_loss: 1.95, D(X)=0.74 D(G(Z))=0.27
# Epoch 45/100, d_loss: 0.84, g_loss: 1.93, D(X)=0.74 D(G(Z))=0.27
# Epoch 46/100, d_loss: 0.88, g_loss: 2.17, D(X)=0.74 D(G(Z))=0.27
# Epoch 47/100, d_loss: 0.90, g_loss: 1.74, D(X)=0.72 D(G(Z))=0.29
# Epoch 48/100, d_loss: 0.89, g_loss: 1.75, D(X)=0.72 D(G(Z))=0.29
# Epoch 49/100, d_loss: 0.90, g_loss: 1.80, D(X)=0.72 D(G(Z))=0.29
# Epoch 50/100, d_loss: 0.90, g_loss: 1.73, D(X)=0.71 D(G(Z))=0.29
# Epoch 51/100, d_loss: 0.88, g_loss: 1.77, D(X)=0.72 D(G(Z))=0.29
# Epoch 52/100, d_loss: 0.87, g_loss: 1.80, D(X)=0.72 D(G(Z))=0.28
# Epoch 53/100, d_loss: 0.90, g_loss: 1.74, D(X)=0.72 D(G(Z))=0.29
# Epoch 54/100, d_loss: 0.87, g_loss: 1.70, D(X)=0.72 D(G(Z))=0.29
# Epoch 55/100, d_loss: 0.90, g_loss: 1.67, D(X)=0.71 D(G(Z))=0.30
# Epoch 56/100, d_loss: 0.90, g_loss: 1.67, D(X)=0.71 D(G(Z))=0.30
# Epoch 57/100, d_loss: 0.91, g_loss: 1.62, D(X)=0.71 D(G(Z))=0.30
# Epoch 58/100, d_loss: 0.91, g_loss: 1.59, D(X)=0.70 D(G(Z))=0.30
# Epoch 59/100, d_loss: 0.92, g_loss: 1.57, D(X)=0.70 D(G(Z))=0.31
# Epoch 60/100, d_loss: 0.93, g_loss: 1.62, D(X)=0.70 D(G(Z))=0.31
# Epoch 61/100, d_loss: 0.93, g_loss: 1.56, D(X)=0.70 D(G(Z))=0.31
# Epoch 62/100, d_loss: 0.95, g_loss: 1.49, D(X)=0.69 D(G(Z))=0.32
# Epoch 63/100, d_loss: 0.95, g_loss: 1.57, D(X)=0.69 D(G(Z))=0.31
# Epoch 64/100, d_loss: 0.96, g_loss: 1.59, D(X)=0.69 D(G(Z))=0.31
# Epoch 65/100, d_loss: 0.96, g_loss: 1.52, D(X)=0.69 D(G(Z))=0.32
# Epoch 66/100, d_loss: 0.97, g_loss: 1.51, D(X)=0.69 D(G(Z))=0.32
# Epoch 67/100, d_loss: 0.96, g_loss: 1.47, D(X)=0.68 D(G(Z))=0.32
# Epoch 68/100, d_loss: 0.98, g_loss: 1.45, D(X)=0.68 D(G(Z))=0.33
# Epoch 69/100, d_loss: 1.01, g_loss: 1.43, D(X)=0.67 D(G(Z))=0.33
# Epoch 70/100, d_loss: 1.00, g_loss: 1.41, D(X)=0.67 D(G(Z))=0.34
# Epoch 71/100, d_loss: 1.02, g_loss: 1.38, D(X)=0.66 D(G(Z))=0.34
# Epoch 72/100, d_loss: 1.02, g_loss: 1.39, D(X)=0.67 D(G(Z))=0.34
# Epoch 73/100, d_loss: 1.02, g_loss: 1.36, D(X)=0.66 D(G(Z))=0.34
# Epoch 74/100, d_loss: 1.02, g_loss: 1.34, D(X)=0.66 D(G(Z))=0.35
# Epoch 75/100, d_loss: 1.03, g_loss: 1.38, D(X)=0.66 D(G(Z))=0.35
# Epoch 76/100, d_loss: 1.05, g_loss: 1.37, D(X)=0.66 D(G(Z))=0.35
# Epoch 77/100, d_loss: 1.07, g_loss: 1.29, D(X)=0.65 D(G(Z))=0.36
# Epoch 78/100, d_loss: 1.05, g_loss: 1.30, D(X)=0.65 D(G(Z))=0.36
# Epoch 79/100, d_loss: 1.06, g_loss: 1.30, D(X)=0.65 D(G(Z))=0.36
# Epoch 80/100, d_loss: 1.08, g_loss: 1.29, D(X)=0.64 D(G(Z))=0.36
# Epoch 81/100, d_loss: 1.09, g_loss: 1.27, D(X)=0.64 D(G(Z))=0.37
# Epoch 82/100, d_loss: 1.08, g_loss: 1.25, D(X)=0.64 D(G(Z))=0.37
# Epoch 83/100, d_loss: 1.08, g_loss: 1.25, D(X)=0.64 D(G(Z))=0.37
# Epoch 84/100, d_loss: 1.09, g_loss: 1.25, D(X)=0.64 D(G(Z))=0.37
# Epoch 85/100, d_loss: 1.09, g_loss: 1.25, D(X)=0.64 D(G(Z))=0.37
# Epoch 86/100, d_loss: 1.08, g_loss: 1.25, D(X)=0.64 D(G(Z))=0.37
# Epoch 87/100, d_loss: 1.09, g_loss: 1.22, D(X)=0.63 D(G(Z))=0.37
# Epoch 88/100, d_loss: 1.10, g_loss: 1.23, D(X)=0.63 D(G(Z))=0.37
# Epoch 89/100, d_loss: 1.09, g_loss: 1.24, D(X)=0.63 D(G(Z))=0.37
# Epoch 90/100, d_loss: 1.10, g_loss: 1.23, D(X)=0.63 D(G(Z))=0.37
# Epoch 91/100, d_loss: 1.11, g_loss: 1.23, D(X)=0.63 D(G(Z))=0.37
# Epoch 92/100, d_loss: 1.10, g_loss: 1.22, D(X)=0.63 D(G(Z))=0.37
# Epoch 93/100, d_loss: 1.10, g_loss: 1.20, D(X)=0.63 D(G(Z))=0.38
# Epoch 94/100, d_loss: 1.11, g_loss: 1.21, D(X)=0.63 D(G(Z))=0.38
# Epoch 95/100, d_loss: 1.12, g_loss: 1.19, D(X)=0.62 D(G(Z))=0.38
# Epoch 96/100, d_loss: 1.12, g_loss: 1.19, D(X)=0.62 D(G(Z))=0.38
# Epoch 97/100, d_loss: 1.13, g_loss: 1.15, D(X)=0.62 D(G(Z))=0.39
# Epoch 98/100, d_loss: 1.14, g_loss: 1.17, D(X)=0.62 D(G(Z))=0.39
# Epoch 99/100, d_loss: 1.13, g_loss: 1.15, D(X)=0.62 D(G(Z))=0.39

# %% [markdown]
# Let's plot some generated images.

# %%
fake_images = fake_images.view(batch, 28, 28).data.numpy()

fig = plt.figure(figsize=(6, 6))
for i in range(100):
    a = fig.add_subplot(10, 10, i + 1)
    a.axis('off')
    fake_image = fake_images[i - 1]
    a.imshow(fake_image, cmap='Greys_r')
